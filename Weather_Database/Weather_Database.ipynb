# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&&lang={en}&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Weather":city_current,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | dunedin
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | ust-tsilma
# Processing Record 5 of Set 1 | nanortalik
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | ancud
# Processing Record 8 of Set 1 | vao
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | kondoa
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | maceio
# Processing Record 18 of Set 1 | malatya
# Processing Record 19 of Set 1 | nouakchott
# Processing Record 20 of Set 1 | caravelas
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | diplo
# Processing Record 25 of Set 1 | henties bay
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | sopotnica
# Processing Record 32 of Set 1 | chinsali
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | pietersburg
# Processing Record 35 of Set 1 | devils lake
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | syedove
# Processing Record 38 of Set 1 | timizart
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | egvekinot
# Processing Record 41 of Set 1 | jipijapa
# Processing Record 42 of Set 1 | kalmunai
# Processing Record 43 of Set 1 | abha
# Processing Record 44 of Set 1 | kaitangata
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | bodaybo
# Processing Record 50 of Set 1 | saskylakh
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | lyubim
# Processing Record 4 of Set 2 | santa cruz
# Processing Record 5 of Set 2 | najran
# Processing Record 6 of Set 2 | harper
# Processing Record 7 of Set 2 | sorong
# Processing Record 8 of Set 2 | guerrero negro
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 2 | pimenta bueno
# Processing Record 12 of Set 2 | micheweni
# Processing Record 13 of Set 2 | erzin
# Processing Record 14 of Set 2 | ixtapa
# Processing Record 15 of Set 2 | rafaela
# Processing Record 16 of Set 2 | lavrentiya
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | peleduy
# Processing Record 20 of Set 2 | gangotri
# City not found. Skipping...
# Processing Record 21 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | longyearbyen
# Processing Record 24 of Set 2 | svetlaya
# Processing Record 25 of Set 2 | ibra
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | kalaleh
# Processing Record 28 of Set 2 | galesong
# Processing Record 29 of Set 2 | port macquarie
# Processing Record 30 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | lompoc
# Processing Record 33 of Set 2 | abu zabad
# Processing Record 34 of Set 2 | padang
# Processing Record 35 of Set 2 | pevek
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | victoria
# Processing Record 38 of Set 2 | maumere
# Processing Record 39 of Set 2 | kuryk
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | port elizabeth
# Processing Record 42 of Set 2 | mugur-aksy
# Processing Record 43 of Set 2 | ha giang
# Processing Record 44 of Set 2 | warrington
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | fortuna
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | upernavik
# Processing Record 50 of Set 2 | cabra
# Processing Record 1 of Set 3 | saint anthony
# Processing Record 2 of Set 3 | airai
# Processing Record 3 of Set 3 | the pas
# Processing Record 4 of Set 3 | sembe
# Processing Record 5 of Set 3 | deputatskiy
# Processing Record 6 of Set 3 | caldwell
# Processing Record 7 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 3 | gamba
# Processing Record 9 of Set 3 | camacha
# Processing Record 10 of Set 3 | khatanga
# Processing Record 11 of Set 3 | sapao
# City not found. Skipping...
# Processing Record 12 of Set 3 | lorengau
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | babu
# Processing Record 17 of Set 3 | gotsu
# Processing Record 18 of Set 3 | carutapera
# Processing Record 19 of Set 3 | yangambi
# Processing Record 20 of Set 3 | goderich
# Processing Record 21 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 22 of Set 3 | zalantun
# Processing Record 23 of Set 3 | eyl
# Processing Record 24 of Set 3 | castelnau-le-lez
# Processing Record 25 of Set 3 | clyde river
# Processing Record 26 of Set 3 | saldanha
# Processing Record 27 of Set 3 | cherskiy
# Processing Record 28 of Set 3 | danilovka
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | kahului
# Processing Record 31 of Set 3 | makakilo city
# Processing Record 32 of Set 3 | hobyo
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | blind river
# Processing Record 35 of Set 3 | mount gambier
# Processing Record 36 of Set 3 | codrington
# Processing Record 37 of Set 3 | mahibadhoo
# Processing Record 38 of Set 3 | ornskoldsvik
# Processing Record 39 of Set 3 | cabras
# Processing Record 40 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | jalu
# Processing Record 43 of Set 3 | sao miguel do araguaia
# Processing Record 44 of Set 3 | vedeno
# Processing Record 45 of Set 3 | ilulissat
# Processing Record 46 of Set 3 | rikitea
# Processing Record 47 of Set 3 | sechura
# Processing Record 48 of Set 3 | la ronge
# Processing Record 49 of Set 3 | kirakira
# Processing Record 50 of Set 3 | wanaka
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | alanya
# Processing Record 3 of Set 4 | broome
# Processing Record 4 of Set 4 | novyy urengoy
# Processing Record 5 of Set 4 | sao joao da barra
# Processing Record 6 of Set 4 | bytow
# Processing Record 7 of Set 4 | luwuk
# Processing Record 8 of Set 4 | nakamura
# Processing Record 9 of Set 4 | san patricio
# Processing Record 10 of Set 4 | faya
# Processing Record 11 of Set 4 | vila velha
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | shawville
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 4 | kilindoni
# Processing Record 17 of Set 4 | borlange
# City not found. Skipping...
# Processing Record 18 of Set 4 | hasaki
# Processing Record 19 of Set 4 | severo-kurilsk
# Processing Record 20 of Set 4 | nikolskoye
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | kitimat
# Processing Record 23 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 4 | kilis
# Processing Record 26 of Set 4 | george
# Processing Record 27 of Set 4 | malakal
# Processing Record 28 of Set 4 | namatanai
# Processing Record 29 of Set 4 | kholm
# Processing Record 30 of Set 4 | mahajanga
# Processing Record 31 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 4 | san andres
# Processing Record 33 of Set 4 | clyde
# Processing Record 34 of Set 4 | kautokeino
# Processing Record 35 of Set 4 | turukhansk
# Processing Record 36 of Set 4 | treinta y tres
# Processing Record 37 of Set 4 | lata
# Processing Record 38 of Set 4 | walvis bay
# Processing Record 39 of Set 4 | trabzon
# Processing Record 40 of Set 4 | garowe
# Processing Record 41 of Set 4 | ahipara
# Processing Record 42 of Set 4 | correntina
# Processing Record 43 of Set 4 | sao lourenco do sul
# Processing Record 44 of Set 4 | tasiilaq
# Processing Record 45 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 4 | sinop
# Processing Record 47 of Set 4 | tautira
# Processing Record 48 of Set 4 | akdepe
# Processing Record 49 of Set 4 | cayenne
# Processing Record 50 of Set 4 | luderitz
# Processing Record 1 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 5 | beyneu
# Processing Record 3 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 5 | vilhena
# Processing Record 5 of Set 5 | fairbanks
# Processing Record 6 of Set 5 | butaritari
# Processing Record 7 of Set 5 | waw
# Processing Record 8 of Set 5 | kamenka
# Processing Record 9 of Set 5 | madison
# Processing Record 10 of Set 5 | shahrud
# Processing Record 11 of Set 5 | poum
# Processing Record 12 of Set 5 | bayshore gardens
# Processing Record 13 of Set 5 | peniche
# Processing Record 14 of Set 5 | beringovskiy
# Processing Record 15 of Set 5 | meulaboh
# Processing Record 16 of Set 5 | chifeng
# Processing Record 17 of Set 5 | xiaoshi
# Processing Record 18 of Set 5 | porto novo
# Processing Record 19 of Set 5 | puerto narino
# Processing Record 20 of Set 5 | cidreira
# Processing Record 21 of Set 5 | iqaluit
# Processing Record 22 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 5 | yemtsa
# Processing Record 24 of Set 5 | ossora
# Processing Record 25 of Set 5 | bethel
# Processing Record 26 of Set 5 | songea
# Processing Record 27 of Set 5 | bambous virieux
# Processing Record 28 of Set 5 | avera
# Processing Record 29 of Set 5 | cravo norte
# Processing Record 30 of Set 5 | bagdarin
# Processing Record 31 of Set 5 | dalby
# Processing Record 32 of Set 5 | ust-koksa
# Processing Record 33 of Set 5 | praia da vitoria
# Processing Record 34 of Set 5 | te anau
# Processing Record 35 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 36 of Set 5 | northam
# Processing Record 37 of Set 5 | arantangi
# Processing Record 38 of Set 5 | khasan
# Processing Record 39 of Set 5 | port hardy
# Processing Record 40 of Set 5 | hualmay
# Processing Record 41 of Set 5 | saint-philippe
# Processing Record 42 of Set 5 | tezu
# Processing Record 43 of Set 5 | serafimovich
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | enid
# Processing Record 46 of Set 5 | yaan
# Processing Record 47 of Set 5 | tingrela
# City not found. Skipping...
# Processing Record 48 of Set 5 | okhotsk
# Processing Record 49 of Set 5 | epernay
# Processing Record 50 of Set 5 | dudinka
# Processing Record 1 of Set 6 | tual
# Processing Record 2 of Set 6 | buyukcavuslu
# Processing Record 3 of Set 6 | joao pinheiro
# Processing Record 4 of Set 6 | katsuura
# Processing Record 5 of Set 6 | caxias
# Processing Record 6 of Set 6 | juliaca
# Processing Record 7 of Set 6 | acapulco
# Processing Record 8 of Set 6 | isangel
# Processing Record 9 of Set 6 | davidson
# Processing Record 10 of Set 6 | tessalit
# Processing Record 11 of Set 6 | vardo
# Processing Record 12 of Set 6 | port keats
# Processing Record 13 of Set 6 | gelibolu
# Processing Record 14 of Set 6 | esperance
# Processing Record 15 of Set 6 | yataity
# Processing Record 16 of Set 6 | havelock
# Processing Record 17 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 6 | qaanaaq
# Processing Record 19 of Set 6 | tondano
# Processing Record 20 of Set 6 | sabha
# Processing Record 21 of Set 6 | saint-francois
# Processing Record 22 of Set 6 | antalaha
# Processing Record 23 of Set 6 | nantucket
# Processing Record 24 of Set 6 | dariba
# Processing Record 25 of Set 6 | haines junction
# Processing Record 26 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 6 | daru
# Processing Record 28 of Set 6 | chengde
# Processing Record 29 of Set 6 | port lincoln
# Processing Record 30 of Set 6 | soverato
# Processing Record 31 of Set 6 | rawson
# Processing Record 32 of Set 6 | tigre
# Processing Record 33 of Set 6 | brae
# Processing Record 34 of Set 6 | fort nelson
# Processing Record 35 of Set 6 | geraldton
# Processing Record 36 of Set 6 | bonanza
# Processing Record 37 of Set 6 | kattivakkam
# Processing Record 38 of Set 6 | ostrovnoy
# Processing Record 39 of Set 6 | dalgopol
# Processing Record 40 of Set 6 | vostok
# Processing Record 41 of Set 6 | taltal
# Processing Record 42 of Set 6 | esna
# Processing Record 43 of Set 6 | kawalu
# Processing Record 44 of Set 6 | ulety
# Processing Record 45 of Set 6 | sibu
# Processing Record 46 of Set 6 | shenzhen
# Processing Record 47 of Set 6 | talnakh
# Processing Record 48 of Set 6 | axim
# Processing Record 49 of Set 6 | manokwari
# Processing Record 50 of Set 6 | vung tau
# Processing Record 1 of Set 7 | sambava
# Processing Record 2 of Set 7 | puerto ayacucho
# Processing Record 3 of Set 7 | ust-kuyga
# Processing Record 4 of Set 7 | dzhida
# Processing Record 5 of Set 7 | yartsevo
# Processing Record 6 of Set 7 | darhan
# Processing Record 7 of Set 7 | boyolangu
# Processing Record 8 of Set 7 | grindavik
# Processing Record 9 of Set 7 | necochea
# Processing Record 10 of Set 7 | adrar
# Processing Record 11 of Set 7 | iracoubo
# Processing Record 12 of Set 7 | grenaa
# Processing Record 13 of Set 7 | berlevag
# Processing Record 14 of Set 7 | tabou
# Processing Record 15 of Set 7 | rorvik
# Processing Record 16 of Set 7 | college
# Processing Record 17 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 7 | oussouye
# Processing Record 19 of Set 7 | sur
# Processing Record 20 of Set 7 | mao
# Processing Record 21 of Set 7 | baruun-urt
# Processing Record 22 of Set 7 | port hawkesbury
# Processing Record 23 of Set 7 | pangnirtung
# Processing Record 24 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 25 of Set 7 | soyo
# Processing Record 26 of Set 7 | badnawar
# Processing Record 27 of Set 7 | keti bandar
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | yumen
# Processing Record 30 of Set 7 | murgab
# Processing Record 31 of Set 7 | itarema
# Processing Record 32 of Set 7 | hede
# Processing Record 33 of Set 7 | porbandar
# Processing Record 34 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 35 of Set 7 | fier
# Processing Record 36 of Set 7 | manado
# Processing Record 37 of Set 7 | gunjur
# Processing Record 38 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 7 | marzuq
# Processing Record 40 of Set 7 | yerbogachen
# Processing Record 41 of Set 7 | opuwo
# Processing Record 42 of Set 7 | ajra
# Processing Record 43 of Set 7 | horqueta
# Processing Record 44 of Set 7 | zaysan
# Processing Record 45 of Set 7 | port blair
# Processing Record 46 of Set 7 | shimoda
# Processing Record 47 of Set 7 | gizo
# Processing Record 48 of Set 7 | takoradi
# Processing Record 49 of Set 7 | amapa
# Processing Record 50 of Set 7 | bengkulu
# Processing Record 1 of Set 8 | farim
# Processing Record 2 of Set 8 | sioux lookout
# Processing Record 3 of Set 8 | hay river
# Processing Record 4 of Set 8 | dhankuta
# Processing Record 5 of Set 8 | sarangani
# Processing Record 6 of Set 8 | inhambane
# Processing Record 7 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 8 | chiredzi
# Processing Record 9 of Set 8 | wilmington
# Processing Record 10 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 8 | shingu
# Processing Record 12 of Set 8 | sabzevar
# Processing Record 13 of Set 8 | monte alegre
# Processing Record 14 of Set 8 | repalle
# Processing Record 15 of Set 8 | flagstaff
# Processing Record 16 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 17 of Set 8 | cabo san lucas
# Processing Record 18 of Set 8 | jiuquan
# Processing Record 19 of Set 8 | makat
# Processing Record 20 of Set 8 | natal
# Processing Record 21 of Set 8 | nome
# Processing Record 22 of Set 8 | byron bay
# Processing Record 23 of Set 8 | brandon
# Processing Record 24 of Set 8 | gazli
# Processing Record 25 of Set 8 | alushta
# Processing Record 26 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 8 | norman wells
# Processing Record 29 of Set 8 | burica
# City not found. Skipping...
# Processing Record 30 of Set 8 | medenychi
# Processing Record 31 of Set 8 | brenham
# Processing Record 32 of Set 8 | dhupgari
# Processing Record 33 of Set 8 | tiksi
# Processing Record 34 of Set 8 | tilichiki
# Processing Record 35 of Set 8 | souillac
# Processing Record 36 of Set 8 | belmonte
# Processing Record 37 of Set 8 | bell ville
# Processing Record 38 of Set 8 | anadyr
# Processing Record 39 of Set 8 | portland
# Processing Record 40 of Set 8 | christchurch
# Processing Record 41 of Set 8 | wuda
# Processing Record 42 of Set 8 | olafsvik
# Processing Record 43 of Set 8 | aykhal
# Processing Record 44 of Set 8 | ixcaquixtla
# City not found. Skipping...
# Processing Record 45 of Set 8 | goulburn
# Processing Record 46 of Set 8 | cape coast
# Processing Record 47 of Set 8 | riosucio
# Processing Record 48 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 8 | kudymkar
# Processing Record 50 of Set 8 | guadalupe y calvo
# Processing Record 1 of Set 9 | praya
# Processing Record 2 of Set 9 | hamilton
# Processing Record 3 of Set 9 | luena
# Processing Record 4 of Set 9 | lakatoro
# Processing Record 5 of Set 9 | yulara
# Processing Record 6 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 7 of Set 9 | flinders
# Processing Record 8 of Set 9 | ulaangom
# Processing Record 9 of Set 9 | paamiut
# Processing Record 10 of Set 9 | barao de melgaco
# Processing Record 11 of Set 9 | ashland
# Processing Record 12 of Set 9 | saint-augustin
# Processing Record 13 of Set 9 | srednekolymsk
# Processing Record 14 of Set 9 | oum hadjer
# Processing Record 15 of Set 9 | broken hill
# Processing Record 16 of Set 9 | dinard
# Processing Record 17 of Set 9 | matagami
# Processing Record 18 of Set 9 | safaga
# Processing Record 19 of Set 9 | hofn
# Processing Record 20 of Set 9 | thanh hoa
# Processing Record 21 of Set 9 | coyuca
# City not found. Skipping...
# Processing Record 22 of Set 9 | sola
# Processing Record 23 of Set 9 | kharan
# Processing Record 24 of Set 9 | nangomba
# Processing Record 25 of Set 9 | maraba
# Processing Record 26 of Set 9 | riyadh
# Processing Record 27 of Set 9 | baicheng
# Processing Record 28 of Set 9 | vila do maio
# Processing Record 29 of Set 9 | holme
# Processing Record 30 of Set 9 | akyab
# Processing Record 31 of Set 9 | naifaru
# Processing Record 32 of Set 9 | sao raimundo nonato
# Processing Record 33 of Set 9 | poso
# Processing Record 34 of Set 9 | suez
# Processing Record 35 of Set 9 | chokurdakh
# Processing Record 36 of Set 9 | mirabad
# Processing Record 37 of Set 9 | labuan
# Processing Record 38 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 39 of Set 9 | kidal
# Processing Record 40 of Set 9 | ukiah
# Processing Record 41 of Set 9 | kieta
# Processing Record 42 of Set 9 | san cristobal
# Processing Record 43 of Set 9 | lubango
# Processing Record 44 of Set 9 | constitucion
# Processing Record 45 of Set 9 | sorland
# Processing Record 46 of Set 9 | yendi
# Processing Record 47 of Set 9 | buraydah
# Processing Record 48 of Set 9 | deoria
# Processing Record 49 of Set 9 | terrace
# Processing Record 50 of Set 9 | lieksa
# Processing Record 1 of Set 10 | komsomolskiy
# Processing Record 2 of Set 10 | dalvik
# Processing Record 3 of Set 10 | biltine
# Processing Record 4 of Set 10 | areka
# Processing Record 5 of Set 10 | hambantota
# Processing Record 6 of Set 10 | velasco ibarra
# Processing Record 7 of Set 10 | irkutsk
# Processing Record 8 of Set 10 | nouadhibou
# Processing Record 9 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 10 of Set 10 | kudowa-zdroj
# Processing Record 11 of Set 10 | lagoa
# Processing Record 12 of Set 10 | palmer
# Processing Record 13 of Set 10 | zyryanka
# Processing Record 14 of Set 10 | gat
# Processing Record 15 of Set 10 | ordu
# Processing Record 16 of Set 10 | cristalina
# Processing Record 17 of Set 10 | klaksvik
# Processing Record 18 of Set 10 | sisimiut
# Processing Record 19 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 10 | ust-ilimsk
# Processing Record 21 of Set 10 | marsaxlokk
# Processing Record 22 of Set 10 | tigil
# Processing Record 23 of Set 10 | qinhuangdao
# Processing Record 24 of Set 10 | kununurra
# Processing Record 25 of Set 10 | palasa
# Processing Record 26 of Set 10 | hukuntsi
# Processing Record 27 of Set 10 | ushumun
# Processing Record 28 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 10 | cap malheureux
# Processing Record 30 of Set 10 | zhuanghe
# Processing Record 31 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 10 | grand gaube
# Processing Record 33 of Set 10 | chuy
# Processing Record 34 of Set 10 | quatre cocos
# Processing Record 35 of Set 10 | tra vinh
# Processing Record 36 of Set 10 | khabary
# Processing Record 37 of Set 10 | brazzaville
# Processing Record 38 of Set 10 | qafsah
# City not found. Skipping...
# Processing Record 39 of Set 10 | bathsheba
# Processing Record 40 of Set 10 | birao
# Processing Record 41 of Set 10 | moree
# Processing Record 42 of Set 10 | baykit
# Processing Record 43 of Set 10 | alofi
# Processing Record 44 of Set 10 | heishan
# Processing Record 45 of Set 10 | naryan-mar
# Processing Record 46 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 47 of Set 10 | pochutla
# Processing Record 48 of Set 10 | bara
# Processing Record 49 of Set 10 | osorno
# Processing Record 50 of Set 10 | unity
# Processing Record 1 of Set 11 | quime
# Processing Record 2 of Set 11 | sungaipenuh
# Processing Record 3 of Set 11 | nalut
# Processing Record 4 of Set 11 | zhigansk
# Processing Record 5 of Set 11 | bronte
# Processing Record 6 of Set 11 | terney
# Processing Record 7 of Set 11 | havre-saint-pierre
# Processing Record 8 of Set 11 | beli potok
# Processing Record 9 of Set 11 | kamyshin
# Processing Record 10 of Set 11 | mazamari
# Processing Record 11 of Set 11 | oda
# Processing Record 12 of Set 11 | torbay
# Processing Record 13 of Set 11 | raga
# Processing Record 14 of Set 11 | bukama
# Processing Record 15 of Set 11 | el faiyum
# City not found. Skipping...
# Processing Record 16 of Set 11 | viedma
# Processing Record 17 of Set 11 | liverpool
# Processing Record 18 of Set 11 | bermejo
# Processing Record 19 of Set 11 | yokadouma
# Processing Record 20 of Set 11 | fort frances
# Processing Record 21 of Set 11 | coquimbo
# Processing Record 22 of Set 11 | coihaique
# Processing Record 23 of Set 11 | barreiras
# Processing Record 24 of Set 11 | shenjiamen
# Processing Record 25 of Set 11 | mitu
# Processing Record 26 of Set 11 | zaragoza
# Processing Record 27 of Set 11 | tura
# Processing Record 28 of Set 11 | bangui
# Processing Record 29 of Set 11 | pitimbu
# Processing Record 30 of Set 11 | rantoul
# Processing Record 31 of Set 11 | richards bay
# Processing Record 32 of Set 11 | katsiveli
# City not found. Skipping...
# Processing Record 33 of Set 11 | asau
# Processing Record 34 of Set 11 | usinsk
# Processing Record 35 of Set 11 | alugan
# Processing Record 36 of Set 11 | san carlos de bariloche
# Processing Record 37 of Set 11 | boke
# Processing Record 38 of Set 11 | suntar
# Processing Record 39 of Set 11 | touros
# Processing Record 40 of Set 11 | half moon bay
# Processing Record 41 of Set 11 | loralai
# Processing Record 42 of Set 11 | arman
# Processing Record 43 of Set 11 | rio branco
# Processing Record 44 of Set 11 | kenai
# Processing Record 45 of Set 11 | shibetsu
# Processing Record 46 of Set 11 | valparaiso
# Processing Record 47 of Set 11 | novikovo
# Processing Record 48 of Set 11 | paungde
# Processing Record 49 of Set 11 | ridgecrest
# Processing Record 50 of Set 11 | isilkul
# Processing Record 1 of Set 12 | taybad
# Processing Record 2 of Set 12 | naze
# Processing Record 3 of Set 12 | ratangarh
# Processing Record 4 of Set 12 | mmabatho
# Processing Record 5 of Set 12 | sovetskiy
# Processing Record 6 of Set 12 | inverell
# Processing Record 7 of Set 12 | san jeronimo
# Processing Record 8 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 12 | dingle
# Processing Record 10 of Set 12 | russell
# Processing Record 11 of Set 12 | karakol
# Processing Record 12 of Set 12 | kemi
# Processing Record 13 of Set 12 | skiros
# City not found. Skipping...
# Processing Record 14 of Set 12 | avallon
# Processing Record 15 of Set 12 | maloye kozino
# City not found. Skipping...
# Processing Record 16 of Set 12 | aitape
# Processing Record 17 of Set 12 | lazi
# Processing Record 18 of Set 12 | chichimila
# Processing Record 19 of Set 12 | sao filipe
# Processing Record 20 of Set 12 | moerai
# Processing Record 21 of Set 12 | sitka
# Processing Record 22 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 23 of Set 12 | fonte boa
# Processing Record 24 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 25 of Set 12 | madaoua
# Processing Record 26 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 12 | ilhabela
# Processing Record 29 of Set 12 | verkhnevilyuysk
# Processing Record 30 of Set 12 | sucre
# Processing Record 31 of Set 12 | keita
# Processing Record 32 of Set 12 | samarai
# Processing Record 33 of Set 12 | narkevychi
# Processing Record 34 of Set 12 | camopi
# Processing Record 35 of Set 12 | union de san antonio
# Processing Record 36 of Set 12 | ziro
# Processing Record 37 of Set 12 | salalah
# Processing Record 38 of Set 12 | lagunas
# Processing Record 39 of Set 12 | ylivieska
# Processing Record 40 of Set 12 | haapsalu
# Processing Record 41 of Set 12 | honiara
# Processing Record 42 of Set 12 | zanzibar
# Processing Record 43 of Set 12 | manicore
# Processing Record 44 of Set 12 | hami
# Processing Record 45 of Set 12 | kajaani
# Processing Record 46 of Set 12 | santa rosa
# Processing Record 47 of Set 12 | volokolamsk
# Processing Record 48 of Set 12 | leningradskiy
# Processing Record 49 of Set 12 | sobolevo
# Processing Record 50 of Set 12 | marigot
# Processing Record 1 of Set 13 | hengshui
# Processing Record 2 of Set 13 | lakes entrance
# Processing Record 3 of Set 13 | camacupa
# Processing Record 4 of Set 13 | iwaki
# Processing Record 5 of Set 13 | kerch
# Processing Record 6 of Set 13 | monrovia
# Processing Record 7 of Set 13 | samatau
# City not found. Skipping...
# Processing Record 8 of Set 13 | mercedes
# Processing Record 9 of Set 13 | visoko
# Processing Record 10 of Set 13 | menongue
# Processing Record 11 of Set 13 | humaita
# Processing Record 12 of Set 13 | kangaatsiaq
# Processing Record 13 of Set 13 | abalak
# Processing Record 14 of Set 13 | boa vista
# Processing Record 15 of Set 13 | caucaia
# Processing Record 16 of Set 13 | miyako
# Processing Record 17 of Set 13 | santa isabel do rio negro
# Processing Record 18 of Set 13 | roald
# Processing Record 19 of Set 13 | macae
# Processing Record 20 of Set 13 | gambela
# Processing Record 21 of Set 13 | albufeira
# Processing Record 22 of Set 13 | garissa
# Processing Record 23 of Set 13 | senador pompeu
# Processing Record 24 of Set 13 | rosetta
# Processing Record 25 of Set 13 | tianpeng
# Processing Record 26 of Set 13 | sindor
# Processing Record 27 of Set 13 | qasigiannguit
# Processing Record 28 of Set 13 | berdigestyakh
# Processing Record 29 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 13 | margate
# Processing Record 31 of Set 13 | qaqortoq
# Processing Record 32 of Set 13 | krasnovka
# Processing Record 33 of Set 13 | rio gallegos
# Processing Record 34 of Set 13 | fraserburgh
# Processing Record 35 of Set 13 | derzhavinsk
# Processing Record 36 of Set 13 | artena
# Processing Record 37 of Set 13 | fayaoue
# Processing Record 38 of Set 13 | callaway
# Processing Record 39 of Set 13 | krasnotorka
# Processing Record 40 of Set 13 | kharabali
# Processing Record 41 of Set 13 | stepnyak
# Processing Record 42 of Set 13 | stephenville
# Processing Record 43 of Set 13 | lazaro cardenas
# Processing Record 44 of Set 13 | kiama
# Processing Record 45 of Set 13 | beloha
# Processing Record 46 of Set 13 | katobu
# Processing Record 47 of Set 13 | mandalgovi
# Processing Record 48 of Set 13 | khalkhal
# Processing Record 49 of Set 13 | banda aceh
# Processing Record 50 of Set 13 | tazovskiy
# Processing Record 1 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 14 | wittenberge
# Processing Record 3 of Set 14 | pisco
# Processing Record 4 of Set 14 | conselheiro pena
# Processing Record 5 of Set 14 | maniitsoq
# Processing Record 6 of Set 14 | aiken
# Processing Record 7 of Set 14 | mehamn
# Processing Record 8 of Set 14 | port hedland
# Processing Record 9 of Set 14 | moose factory
# Processing Record 10 of Set 14 | mayumba
# Processing Record 11 of Set 14 | belle fourche
# Processing Record 12 of Set 14 | kastamonu
# Processing Record 13 of Set 14 | bubaque
# Processing Record 14 of Set 14 | roswell
# Processing Record 15 of Set 14 | carballo
# Processing Record 16 of Set 14 | ojinaga
# Processing Record 17 of Set 14 | iskateley
# Processing Record 18 of Set 14 | labuhan
# Processing Record 19 of Set 14 | arawa
# Processing Record 20 of Set 14 | balkanabat
# Processing Record 21 of Set 14 | coxim
# Processing Record 22 of Set 14 | luau
# Processing Record 23 of Set 14 | namanga
# Processing Record 24 of Set 14 | karratha
# Processing Record 25 of Set 14 | jhanjharpur
# Processing Record 26 of Set 14 | misratah
# Processing Record 27 of Set 14 | pacific grove
# Processing Record 28 of Set 14 | hlobyne
# Processing Record 29 of Set 14 | ormara
# Processing Record 30 of Set 14 | qandala
# Processing Record 31 of Set 14 | birin
# Processing Record 32 of Set 14 | lac-megantic
# Processing Record 33 of Set 14 | viransehir
# Processing Record 34 of Set 14 | kungurtug
# Processing Record 35 of Set 14 | maiduguri
# Processing Record 36 of Set 14 | ajdabiya
# Processing Record 37 of Set 14 | mezen
# Processing Record 38 of Set 14 | nha trang
# Processing Record 39 of Set 14 | carnduff
# Processing Record 40 of Set 14 | raudeberg
# Processing Record 41 of Set 14 | chivilcoy
# Processing Record 42 of Set 14 | nyaunglebin
# Processing Record 43 of Set 14 | thalgau
# Processing Record 44 of Set 14 | podgorenskiy
# Processing Record 45 of Set 14 | bagan
# Processing Record 46 of Set 14 | oran
# Processing Record 47 of Set 14 | aklavik
# Processing Record 48 of Set 14 | atar
# Processing Record 49 of Set 14 | amarillo
# Processing Record 50 of Set 14 | boguchany
# Processing Record 1 of Set 15 | susehri
# Processing Record 2 of Set 15 | antsohihy
# Processing Record 3 of Set 15 | nemuro
# Processing Record 4 of Set 15 | chikhli
# Processing Record 5 of Set 15 | eydhafushi
# Processing Record 6 of Set 15 | neiafu
# Processing Record 7 of Set 15 | bayangol
# Processing Record 8 of Set 15 | nioro
# Processing Record 9 of Set 15 | kysyl-syr
# Processing Record 10 of Set 15 | pokhara
# Processing Record 11 of Set 15 | kirovsk
# Processing Record 12 of Set 15 | mkushi
# Processing Record 13 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 15 | grevesmuhlen
# Processing Record 16 of Set 15 | tucurui
# Processing Record 17 of Set 15 | surt
# Processing Record 18 of Set 15 | shellbrook
# Processing Record 19 of Set 15 | mecca
# Processing Record 20 of Set 15 | oistins
# Processing Record 21 of Set 15 | mayo
# Processing Record 22 of Set 15 | ust-omchug
# Processing Record 23 of Set 15 | jibuti
# Processing Record 24 of Set 15 | reyes
# Processing Record 25 of Set 15 | tarakan
# Processing Record 26 of Set 15 | salinas
# Processing Record 27 of Set 15 | sharjah
# Processing Record 28 of Set 15 | kismayo
# Processing Record 29 of Set 15 | chingirlau
# Processing Record 30 of Set 15 | jiaonan
# Processing Record 31 of Set 15 | orkney
# Processing Record 32 of Set 15 | mwingi
# Processing Record 33 of Set 15 | umm lajj
# Processing Record 34 of Set 15 | mikhaylovka
# Processing Record 35 of Set 15 | black river
# Processing Record 36 of Set 15 | iguape
# Processing Record 37 of Set 15 | nogales
# Processing Record 38 of Set 15 | frankfort
# Processing Record 39 of Set 15 | xining
# Processing Record 40 of Set 15 | merauke
# Processing Record 41 of Set 15 | kupang
# Processing Record 42 of Set 15 | basoko
# Processing Record 43 of Set 15 | porosozero
# Processing Record 44 of Set 15 | chyhyryn
# Processing Record 45 of Set 15 | biak
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Hermanus -34.4187   19.2345     65.80        75           2       14.29
# 1     Dunedin -45.8742  170.5036     61.81        89         100        1.99
# 2   Jamestown  42.0970  -79.2353     17.10        49           0        5.99
# 3  Ust-Tsilma  65.4410   52.1498     17.02        92         100        9.57
# 4  Nanortalik  60.1432  -45.2371     19.49        68         100       12.15
#
#   Country  Current Weather                 Date
# 0      ZA        clear sky  2022-01-29 20:08:40
# 1      NZ  overcast clouds  2022-01-29 20:13:17
# 2      US        clear sky  2022-01-29 20:10:13
# 3      RU       light snow  2022-01-29 20:13:18
# 4      GL       light snow  2022-01-29 20:13:18

# %%
columns = list(city_data_df)
print(columns)

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]

city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Hermanus      ZA -34.4187   19.2345     65.80        75           2
# 1     Dunedin      NZ -45.8742  170.5036     61.81        89         100
# 2   Jamestown      US  42.0970  -79.2353     17.10        49           0
# 3  Ust-Tsilma      RU  65.4410   52.1498     17.02        92         100
# 4  Nanortalik      GL  60.1432  -45.2371     19.49        68         100
#
#    Wind Speed  Current Weather
# 0       14.29        clear sky
# 1        1.99  overcast clouds
# 2        5.99        clear sky
# 3        9.57       light snow
# 4       12.15       light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
